# %% [markdown]
# ##**Assignment on NumPy, Pandas, Matplotlib and Seaborn**

# %% [markdown]
# Do the following operation on Iris dataset:
# 1. Read the dataset to python environment.
# 2. Display the columns in the dataset.
# 3. Calculate the mean of each column of the dataset.
# 4. Check for the null values present in the dataset.
# 5. Perform meaningful visualizations using the dataset. Bring at least 3
# visualizations.

# %%
import pandas as pd

# %% [markdown]
# 1. Read the dataset to python environment.

# %%
data = pd.read_excel('/content/iris.xls')
print('Iris Dataset')
data
# Out:
# Iris Dataset
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 2. Display the columns in the dataset.

# %%
columns = data.columns
print(columns)
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# 3. Calculate the mean of each column of the dataset.

# %%
col_mean =data[['SL','SW','PL','PW']].mean()
print('Mean Value of each column of the dataset: ')
print(col_mean)
# Out:
# Mean Value of each column of the dataset:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# 4. Check for the null values present in the dataset

# %%
data_nullvalues = data.isnull().sum()
print('Null Values: ')
print(data_nullvalues)
# Out:
# Null Values:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# 5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %%
import matplotlib.pyplot as plt

# %%
#Bar plot of SL vs Classification in Iris Data
plt.bar(data['SL'],data['Classification'])
plt.title('SL vs Classification')
plt.xlabel('SL')
plt.ylabel('Classification')
# Out:
# Text(0, 0.5, 'Classification')

# %%
# Histogram of Classification in Iris Data
plt.hist(data['Classification'])
# Out:
# (array([50.,  0.,  0.,  0.,  0., 50.,  0.,  0.,  0., 50.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
# Boxplot of SL, SW, PL and PW in Iris Data
plt.boxplot(data[['SL','SW','PL','PW']])
plt.show()

# %%
# Seaborn Pairplot of Iris Data
import seaborn as sns
sns.pairplot(data)

# %%
# Scatter plot of Iris Data
plt.scatter(data['SL'],data['SW'],data['PL'],data['PW'])
